# %%
import json
import numpy as np
from kafka import KafkaConsumer
from datetime import datetime

# Secure JSON deserializer
def safe_json_deserializer(v):
    try:
        decoded_value = v.decode('utf-8')
        return json.loads(decoded_value)  # Deserialize to a dictionary
    except Exception as e:
        print(f"[ERROR] Unable to parse data: {v}，Wrong message: {e}")
        return None  

# Compute VaR and ES
def compute_var_es(returns, confidence_level=0.95):
    """
    Compute Value at Risk（VaR）and Expected Shortfall（ES）
    :param returns: A list of asset returns
    :param confidence_level: confidence level（95%）
    :return: VaR and ES
    """
    if len(returns) == 0:
        return None, None  # avoid mistakes caused by empty dataset

    var_threshold = np.percentile(returns, (1 - confidence_level) * 100)
    es = np.mean([r for r in returns if r <= var_threshold])
    return var_threshold, es

# Kafka Consumer set
consumer = KafkaConsumer(
    'stock_index_topic',
    bootstrap_servers='localhost:9092',
    auto_offset_reset='earliest',
    enable_auto_commit=False,
    group_id=f'read-all-history-group-{datetime.now().timestamp()}',
    value_deserializer=safe_json_deserializer
)

prices = []

print("Consumer has started and is listening 'stock_index_topic' data...")

# receive messages, compute VaR and ES
for message in consumer:
    # get original JSON data
    data = message.value
    if data:

        # get date, time, last price and stock code
        try:
            date_str = data.get("date")  
            time_str = data.get("time")  
            last_price = data.get("last_price")  
            stock_code = data.get("stock_code")

            # make sure get data
            if date_str and time_str and last_price:
                # combine date and exact time, then transfer
                timestamp_str = f"{date_str} {time_str}"  # eg. "2025-03-26 15:43:58"
                timestamp_sgt = datetime.strptime(timestamp_str, "%Y-%m-%d %H:%M:%S")


                prices.append(last_price)

                if len(prices) > 1:
                    returns = np.diff(prices) / prices[:-1]  

                    var, es = compute_var_es(returns, confidence_level=0.95)
                    print(f"[VaR & ES] Stock Code: {stock_code} Time: {timestamp_sgt}, Latest VaR(95%): {var:.4f}, ES(95%): {es:.4f}")
        except Exception as e:
            print(f"[ERROR] Data parsing failed, Wrong message: {e}")
            continue
# Out:
# Consumer has started and is listening 'stock_index_topic' data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 45
#      42 print("Consumer has started and is listening 'stock_index_topic' data...")
#      44 # receive messages, compute VaR and ES
# ---> 45 for message in consumer:
#      46     # get original JSON data
#      47     data = message.value
#      48     if data:
#      49
#      50         # get date, time, last price and stock code
#
# File ~\AppData\Roaming\Python\Python312\site-packages\kafka\consumer\group.py:1180, in KafkaConsumer.__next__(self)
#    1178     self._iterator = self._message_generator_v2()
#    1179 try:
# -> 1180     return next(self._iterator)
#    1181 except StopIteration:
#    1182     self._iterator = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\kafka\consumer\group.py:1152, in KafkaConsumer._message_generator_v2(self)
#    1150 def _message_generator_v2(self):
#    1151     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1152     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1153     for tp, records in six.iteritems(record_map):
#    1154         # Generators are stateful, and it is possible that the tp / records
#    1155         # here may become stale during iteration -- i.e., we seek to a
#    1156         # different offset, pause consumption, or lose assignment.
#    1157         for record in records:
#    1158             # is_fetchable(tp) should handle assignment changes and offset
#    1159             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1160             # outer function destroying the existing iterator/generator
#    1161             # via self._iterator = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\kafka\consumer\group.py:688, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     686 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     687 while not self._closed:
# --> 688     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     689     if records:
#     690         return records
#
# File ~\AppData\Roaming\Python\Python312\site-packages\kafka\consumer\group.py:731, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     728 if records:
#     729     return records
# --> 731 self._client.poll(timeout_ms=inner_timeout_ms(self._coordinator.time_to_next_poll() * 1000))
#     732 # after the long poll, we should check whether the group needs to rebalance
#     733 # prior to returning data so that the group can stabilize faster
#     734 if self._coordinator.need_rejoin():
#
# File ~\AppData\Roaming\Python\Python312\site-packages\kafka\client_async.py:684, in KafkaClient.poll(self, timeout_ms, future)
#     677         timeout = min(
#     678             user_timeout_ms,
#     679             metadata_timeout_ms,
#     680             idle_connection_timeout_ms,
#     681             request_timeout_ms)
#     682         timeout = max(0, timeout)  # avoid negative timeouts
# --> 684     self._poll(timeout / 1000)
#     686 # called without the lock to avoid deadlock potential
#     687 # if handlers need to acquire locks
#     688 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\kafka\client_async.py:727, in KafkaClient._poll(self, timeout)
#     724 self._register_send_sockets()
#     726 start_select = time.time()
# --> 727 ready = self._selector.select(timeout)
#     728 end_select = time.time()
#     729 if self._sensors:
#
# File c:\Program Files\Python312\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File c:\Program Files\Python312\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:

# %%
import json
from kafka import KafkaConsumer
from datetime import datetime

def safe_json_deserializer(v):
    try:
        decoded_value = v.decode('utf-8')
        return json.loads(decoded_value)
    except Exception as e:
        print(f"[ERROR] Unable to parse data: {v}，Wrong message: {e}")
        return None  

consumer = KafkaConsumer(
    'stock_index_topic',
    bootstrap_servers='localhost:9092',
    auto_offset_reset='earliest',
    enable_auto_commit=False,
    group_id=f'read-all-history-group-{datetime.now().timestamp()}',
    value_deserializer=safe_json_deserializer
)

for message in consumer:
    print(f"[DEBUG] receive message: {message.value}")  # make sure Consumer is receiving messages
# Out:
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:43:58', 'last_price': 3967.87}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:01', 'last_price': 3967.6}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:04', 'last_price': 3967.75}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:07', 'last_price': 3967.73}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:10', 'last_price': 3967.76}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:13', 'last_price': 3967.92}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:16', 'last_price': 3966.79}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:19', 'last_price': 3966.76}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:22', 'last_price': 3967.39}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:26', 'last_price': 3967.47}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:29', 'last_price': 3966.52}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:32', 'last_price': 3966.39}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:35', 'last_price': 3966.78}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:38', 'last_price': 3967.2}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:41', 'last_price': 3967.36}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:44', 'last_price': 3967.42}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:47', 'last_price': 3967.39}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:50', 'last_price': 3967.42}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:53', 'last_price': 3966.15}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:56', 'last_price': 3966.5}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:44:59', 'last_price': 3966.6}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:45:02', 'last_price': 3966.49}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:45:05', 'last_price': 3967.09}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:45:08', 'last_price': 3967.07}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:45:12', 'last_price': 3967.07}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15:45:15', 'last_price': 3966.86}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-26', 'time': '15

# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-27', 'time': '16:46:38', 'last_price': 3978.03}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-27', 'time': '16:46:41', 'last_price': 3977.69}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-27', 'time': '16:46:44', 'last_price': 3978.0}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-27', 'time': '16:46:48', 'last_price': 3978.13}
# [DEBUG] 接收到消息: {'stock_code': 'STI', 'date': '2025-03-27', 'time': '16:46:51', 'last_price': 3978.13}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 22
#      11         return None  # 避免崩溃
#      13 consumer = KafkaConsumer(
#      14     'stock_index_topic',
#      15     bootstrap_servers='localhost:9092',
#    (...)
#      19     value_deserializer=safe_json_deserializer
#      20 )
# ---> 22 for message in consumer:
#      23     print(f"[DEBUG] 接收到消息: {message.value}")
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:1180, in KafkaConsumer.__next__(self)
#    1178     self._iterator = self._message_generator_v2()
#    1179 try:
# -> 1180     return next(self._iterator)
#    1181 except StopIteration:
#    1182     self._iterator = None
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:1152, in KafkaConsumer._message_generator_v2(self)
#    1150 def _message_generator_v2(self):
#    1151     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1152     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1153     for tp, records in six.iteritems(record_map):
#    1154         # Generators are stateful, and it is possible that the tp / records
#    1155         # here may become stale during iteration -- i.e., we seek to a
#    1156         # different offset, pause consumption, or lose assignment.
#    1157         for record in records:
#    1158             # is_fetchable(tp) should handle assignment changes and offset
#    1159             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1160             # outer function destroying the existing iterator/generator
#    1161             # via self._iterator = None
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:688, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     686 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     687 while not self._closed:
# --> 688     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     689     if records:
#     690         return records
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:731, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     728 if records:
#     729     return records
# --> 731 self._client.poll(timeout_ms=inner_timeout_ms(self._coordinator.time_to_next_poll() * 1000))
#     732 # after the long poll, we should check whether the group needs to rebalance
#     733 # prior to returning data so that the group can stabilize faster
#     734 if self._coordinator.need_rejoin():
#
# File ~\anaconda3\Lib\site-packages\kafka\client_async.py:684, in KafkaClient.poll(self, timeout_ms, future)
#     677         timeout = min(
#     678             user_timeout_ms,
#     679             metadata_timeout_ms,
#     680             idle_connection_timeout_ms,
#     681             request_timeout_ms)
#     682         timeout = max(0, timeout)  # avoid negative timeouts
# --> 684     self._poll(timeout / 1000)
#     686 # called without the lock to avoid deadlock potential
#     687 # if handlers need to acquire locks
#     688 responses.extend(self._fire_pending_completed_requests())
#
# File ~\anaconda3\Lib\site-packages\kafka\client_async.py:727, in KafkaClient._poll(self, timeout)
#     724 self._register_send_sockets()
#     726 start_select = time.time()
# --> 727 ready = self._selector.select(timeout)
#     728 end_select = time.time()
#     729 if self._sensors:
#
# File ~\anaconda3\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File ~\anaconda3\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:
